# %% [markdown]
# # PREPROCESSING

# %% [markdown]
# **PROBLEMS IN THE DATASET:**
#
# 1. MISSING VALUES

# %% [markdown]
# ![image.png](attachment:5b6c4d6c-2e6c-4f90-a166-61b83df17b7d.png)

# %% [markdown]
# ![Screenshot 2025-02-25 124141.png](attachment:290a8d50-9c27-4715-9def-e2a92702afbb.png)

# %% [markdown]
# ![Screenshot 2025-02-25 124254.png](attachment:4d548f8b-488a-445e-8fb0-39f5e2e87eb3.png)

# %% [markdown]
# 2. SWAPPED DATA

# %% [markdown]
# ![Screenshot 2025-02-25 124432.png](attachment:ca514619-6461-435c-9ff8-43ee12f118fe.png)

# %% [markdown]
# 3. INVALID DATA

# %% [markdown]
# ![Screenshot 2025-02-25 124618.png](attachment:38631073-96c6-4bb5-9f8a-045165fcf4aa.png)

# %% [markdown]
# # CLEANED DATASET

# %% [markdown]
# ![Screenshot 2025-02-25 124850.png](attachment:c5f8e509-423b-4828-9334-ad037b47c694.png)

# %% [markdown]
# # TREND ANALYSIS

# %% [markdown]
# **The Infrastrcuture Machineries follow the specific cyclic order**

# %% [markdown]
# ![Screenshot 2025-02-25 125153.png](attachment:330620e3-59ae-4c06-8f8e-7e4671adcae2.png)

# %% [markdown]
# **CORRECTED THE ERROR VALUES USING THE NEIGHBOURING VALUES**

# %% [markdown]
# ![Screenshot 2025-02-25 125838.png](attachment:01f48efc-70e5-4981-b6f7-9bd0c4871950.png)

# %% [markdown]
# # Exploratory Data Analysis
